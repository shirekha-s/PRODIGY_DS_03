# %%
# !pip install numpy
# !pip install matplot
# !pip install seaborn
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in c:\users\shirekha\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplot in c:\users\shirekha\anaconda3\lib\site-packages (0.1.9)
# Requirement already satisfied: pyloco>=0.0.134 in c:\users\shirekha\anaconda3\lib\site-packages (from matplot) (0.0.139)
# Requirement already satisfied: matplotlib>=3.1.1 in c:\users\shirekha\anaconda3\lib\site-packages (from matplot) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.8.2)
# Requirement already satisfied: ushlex in c:\users\shirekha\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: websocket-client in c:\users\shirekha\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (0.58.0)
# Requirement already satisfied: twine in c:\users\shirekha\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (5.1.0)
# Requirement already satisfied: typing in c:\users\shirekha\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: SimpleWebSocketServer in c:\users\shirekha\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\shirekha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.16.0)
# Requirement already satisfied: pkginfo>=1.8.1 in c:\users\shirekha\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.9.6)
# Requirement already satisfied: readme-renderer>=35.0 in c:\users\shirekha\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (43.0)
# Requirement already satisfied: requests>=2.20 in c:\users\shirekha\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.31.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in c:\users\shirekha\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\shirekha\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.7)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\shirekha\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (7.0.1)
# Requirement already satisfied: keyring>=15.1 in c:\users\shirekha\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (23.13.1)
# Requirement already satisfied: rfc3986>=1.4.0 in c:\users\shirekha\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.0)
# Requirement already satisfied: rich>=12.0.0 in c:\users\shirekha\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (13.3.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\shirekha\anaconda3\lib\site-packages (from importlib-metadata>=3.6->twine->pyloco>=0.0.134->matplot) (3.17.0)
# Requirement already satisfied: jaraco.classes in c:\users\shirekha\anaconda3\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (3.2.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\shirekha\anaconda3\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (0.2.0)
# Requirement already satisfied: nh3>=0.2.14 in c:\users\shirekha\anaconda3\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.2.17)
# Requirement already satisfied: docutils>=0.13.1 in c:\users\shirekha\anaconda3\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.18.1)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\shirekha\anaconda3\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shirekha\anaconda3\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shirekha\anaconda3\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shirekha\anaconda3\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\shirekha\anaconda3\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shirekha\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.0)
# Requirement already satisfied: more-itertools in c:\users\shirekha\anaconda3\lib\site-packages (from jaraco.classes->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (10.1.0)
# Requirement already satisfied: seaborn in c:\users\shirekha\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\shirekha\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in c:\users\shirekha\anaconda3\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\shirekha\anaconda3\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shirekha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shirekha\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shirekha\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\shirekha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: pandas in c:\users\shirekha\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\shirekha\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shirekha\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shirekha\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shirekha\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\shirekha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import  warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\Shirekha\Desktop\prodigy\task3\bank-additional\bank-additional.csv',delimiter=';')
df.rename(columns={'y':'deposit'}, inplace=True)
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  deposit
# 0         -1.8          92.893          -46.2      1.313       5099.1       no
# 1          1.1          93.994          -36.4      4.855       5191.0       no
# 2          1.4          94.465          -41.8      4.962       5228.1       no
# 3          1.4          94.465          -41.8      4.959       5228.1       no
# 4         -0.1          93.200          -42.0      4.191       5195.8       no
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  deposit
# 0         -1.8          92.893          -46.2      1.313       5099.1       no
# 1          1.1          93.994          -36.4      4.855       5191.0       no
# 2          1.4          94.465          -41.8      4.962       5228.1       no
# 3          1.4          94.465          -41.8      4.959       5228.1       no
# 4         -0.1          93.200          -42.0      4.191       5195.8       no
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#       age         job  marital    education default housing loan    contact  \
# 4114   30      admin.  married     basic.6y      no     yes  yes   cellular
# 4115   39      admin.  married  high.school      no     yes   no  telephone
# 4116   27     student   single  high.school      no      no   no   cellular
# 4117   58      admin.  married  high.school      no      no   no   cellular
# 4118   34  management   single  high.school      no     yes   no   cellular
#
#      month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 4114   jul         thu  ...         1    999         0  nonexistent
# 4115   jul         fri  ...         1    999         0  nonexistent
# 4116   may         mon  ...         2    999         1      failure
# 4117   aug         fri  ...         1    999         0  nonexistent
# 4118   nov         wed  ...         1    999         0  nonexistent
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 4114          1.4          93.918          -42.7      4.958       5228.1
# 4115          1.4          93.918          -42.7      4.959       5228.1
# 4116         -1.8          92.893          -46.2      1.354       5099.1
# 4117          1.4          93.444          -36.1      4.966       5228.1
# 4118         -0.1          93.200          -42.0      4.120       5195.8
#
#       deposit
# 4114       no
# 4115       no
# 4116       no
# 4117       no
# 4118       no
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (4119, 21)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'deposit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# deposit            object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object     11
# int64       5
# float64     5
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
#  17  cons.conf.idx   4119 non-null   float64
#  18  euribor3m       4119 non-null   float64
#  19  nr.employed     4119 non-null   float64
#  20  deposit         4119 non-null   object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 675.9+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# deposit           0
# dtype: int64

# %%
cat_cols = df.select_dtypes(include='object').columns
print(cat_cols)

num_cols=df.select_dtypes(exclude='object').columns
print(num_cols)
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'deposit'],
#       dtype='object')
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# min       -3.400000       92.201000     -50.800000     0.635000  4963.600000
# 25%       -1.800000       93.075000     -42.700000     1.334000  5099.100000
# 50%        1.100000       93.749000     -41.800000     4.857000  5191.000000
# 75%        1.400000       93.994000     -36.400000     4.961000  5228.100000
# max        1.400000       94.767000     -26.900000     5.045000  5228.100000

# %%
df.describe(include='object')
# Out:
#            job  marital          education default housing  loan   contact  \
# count     4119     4119               4119    4119    4119  4119      4119
# unique      12        4                  8       3       3     3         2
# top     admin.  married  university.degree      no     yes    no  cellular
# freq      1012     2509               1264    3315    2175  3349      2652
#
#        month day_of_week     poutcome deposit
# count   4119        4119         4119    4119
# unique    10           5            3       2
# top      may         thu  nonexistent      no
# freq    1378         860         3523    3668

# %%
df.hist(figsize=(10,10),color='#cc5500')
plt.show()

# %%
for feature in cat_cols:
    plt.figure(figsize=(5,5))
    sns.countplot(x=feature, data=df, palette='Wistia')
    plt.title(f'Bar Plot of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.xticks(rotation=90)
    plt.show()

# %%
df.plot(kind='box' , subplots=True,layout=(2,5),figsize=(20,10),color='#7b3f00')
plt.show()

# %%
column = df [['age','campaign','duration']]
q1 = np.percentile(column,25)
q3 = np.percentile(column,75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df[['age','campagin','duration']]= column[(column > lower_bound) & (column < upper_bound)]

# %%
df.plot(kind='box',subplots=True,layout=(3,4),figsize=(20,10),color='#808000')
plt.show()

# %%
df_encoded = pd.get_dummies(df)
corr = df_encoded.corr()
print(corr)
threshold = 0.90
filtered_corr = corr.where(abs(corr) >= threshold)
sns.heatmap(filtered_corr,annot=True,cmap='Set3',linewidths=0.2)
plt.show()
# Out:
#                            age  duration  campaign     pdays  previous  \
# age                   1.000000  0.014048 -0.014169 -0.043425  0.050931
# duration              0.014048  1.000000 -0.218111 -0.093694  0.094206
# campaign             -0.014169 -0.218111  1.000000  0.058742 -0.091490
# pdays                -0.043425 -0.093694  0.058742  1.000000 -0.587941
# previous              0.050931  0.094206 -0.091490 -0.587941  1.000000
# ...                        ...       ...       ...       ...       ...
# poutcome_failure      0.009804  0.042581 -0.079376 -0.001093  0.661990
# poutcome_nonexistent -0.031205 -0.084067  0.098957  0.488761 -0.854241
# poutcome_success      0.043341  0.096224 -0.054564 -0.940565  0.510865
# deposit_no           -0.060374 -0.150733  0.076091  0.332012 -0.255697
# deposit_yes           0.060374  0.150733 -0.076091 -0.332012  0.255697
#
#                       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                      -0.019192       -0.000482       0.098135  -0.015033
# duration                 -0.063870       -0.013338       0.045889  -0.067815
# campaign                  0.176079        0.145021       0.007882   0.159435
# pdays                     0.270684        0.058472      -0.092090   0.301478
# previous                 -0.415238       -0.164922      -0.051420  -0.458851
# ...                            ...             ...            ...        ...
# poutcome_failure         -0.392091       -0.290440      -0.163486  -0.399856
# poutcome_nonexistent      0.482106        0.289799       0.100217   0.502340
# poutcome_success         -0.256587       -0.060257       0.087382  -0.282272
# deposit_no                0.283216        0.098326      -0.054393   0.298565
# deposit_yes              -0.283216       -0.098326       0.054393  -0.298565
#
#                       nr.employed  ...  day_of_week_fri  day_of_week_mon  \
# age                     -0.041936  ...        -0.002192         0.025359
# duration                -0.097339  ...        -0.030667        -0.004992
# campaign                 0.161037  ...         0.019755         0.023227
# pdays                    0.381983  ...         0.002751        -0.011757
# previous                -0.514853  ...         0.007849         0.012444
# ...                           ...  ...              ...              ...
# poutcome_failure        -0.365215  ...         0.014631        -0.006191
# poutcome_nonexistent     0.508717  ...        -0.012180         0.001216
# poutcome_success        -0.354030  ...        -0.001627         0.008283
# deposit_no               0.349241  ...         0.002177        -0.008404
# deposit_yes             -0.349241  ...        -0.002177         0.008404
#
#                       day_of_week_thu  day_of_week_tue  day_of_week_wed  \
# age                         -0.005081         0.043129        -0.062716
# duration                    -0.001043         0.010935         0.025447
# campaign                    -0.006292         0.001210        -0.038121
# pdays                       -0.001868        -0.016659         0.028307
# previous                    -0.005172        -0.000082        -0.015124
# ...                               ...              ...              ...
# poutcome_failure            -0.001507        -0.010954         0.004664
# poutcome_nonexistent        -0.002652         0.001179         0.012298
# poutcome_success             0.007701         0.016529        -0.031719
# deposit_no                  -0.003513         0.002089         0.007972
# deposit_yes                  0.003513        -0.002089        -0.007972
#
#                       poutcome_failure  poutcome_nonexistent  \
# age                           0.009804             -0.031205
# duration                      0.042581             -0.084067
# campaign                     -0.079376              0.098957
# pdays                        -0.001093              0.488761
# previous                      0.661990             -0.854241
# ...                                ...                   ...
# poutcome_failure              1.000000             -0.855705
# poutcome_nonexistent         -0.855705              1.000000
# poutcome_success             -0.066505             -0.459409
# deposit_no                   -0.042927              0.207179
# deposit_yes                   0.042927             -0.207179
#
#                       poutcome_success  deposit_no  deposit_yes
# age                           0.043341   -0.060374     0.060374
# duration                      0.096224   -0.150733     0.150733
# campaign                     -0.054564    0.076091    -0.076091
# pdays                        -0.940565    0.332012    -0.332012
# previous                      0.510865   -0.255697     0.255697
# ...                                ...         ...          ...
# poutcome_failure             -0.066505   -0.042927     0.042927
# poutcome_nonexistent         -0.459409    0.207179    -0.207179
# poutcome_success              1.000000   -0.325804     0.325804
# deposit_no                   -0.325804    1.000000    -1.000000
# deposit_yes                   0.325804   -1.000000     1.000000
#
# [66 rows x 66 columns]

# %%
high_corr_cols =['emp.var.rate','euribor3m','nr.employed']

# %%
df1 = df.copy()
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'deposit', 'campagin'],
#       dtype='object')

# %%
df1.shape
# Out:
# (4119, 22)

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
df_encoded = df1.apply(lb.fit_transform)
df_encoded
# Out:
#       age  job  marital  education  default  housing  loan  contact  month  \
# 0      12    1        1          2        0        2     0        0      6
# 1      21    7        2          3        0        0     0        1      6
# 2       7    7        1          3        0        2     0        1      4
# 3      20    7        1          2        0        1     1        1      4
# 4      29    0        1          6        0        2     0        0      7
# ...   ...  ...      ...        ...      ...      ...   ...      ...    ...
# 4114   12    0        1          1        0        2     2        0      3
# 4115   21    0        1          3        0        2     0        1      3
# 4116    9    8        2          3        0        0     0        0      6
# 4117   40    0        1          3        0        0     0        0      1
# 4118   16    4        2          3        0        2     0        0      7
#
#       day_of_week  ...  pdays  previous  poutcome  emp.var.rate  \
# 0               0  ...     20         0         1             3
# 1               0  ...     20         0         1             8
# 2               4  ...     20         0         1             9
# 3               0  ...     20         0         1             9
# 4               1  ...     20         0         1             7
# ...           ...  ...    ...       ...       ...           ...
# 4114            2  ...     20         0         1             9
# 4115            0  ...     20         0         1             9
# 4116            1  ...     20         1         0             3
# 4117            0  ...     20         0         1             9
# 4118            4  ...     20         0         1             7
#
#       cons.price.idx  cons.conf.idx  euribor3m  nr.employed  deposit  campagin
# 0                  8              4        156            6        0         1
# 1                 18             16        207            8        0         3
# 2                 23              8        225           10        0         0
# 3                 23              8        222           10        0         2
# 4                 11              7        201            9        0         0
# ...              ...            ...        ...          ...      ...       ...
# 4114              17              6        221           10        0         0
# 4115              17              6        222           10        0         0
# 4116               8              4        160            6        0         1
# 4117              13             17        229           10        0         0
# 4118              11              7        199            9        0         0
#
# [4119 rows x 22 columns]

# %%
df_encoded['deposit'].value_counts()
# Out:
# deposit
# 0    3668
# 1     451
# Name: count, dtype: int64

# %%
x = df_encoded.drop('deposit',axis=1)
y = df_encoded['deposit']
print(x.shape)
print(y.shape)
print(type(x))
print(type(y))
# Out:
# (4119, 21)
# (4119,)
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
from sklearn.model_selection import train_test_split

print(4119*0.25)
# Out:
# 1029.75

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3089, 21)
# (1030, 21)
# (3089,)
# (1030,)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

def eval_model(y_test,y_pred):
    acc=accuracy_score(y_test,y_pred)
    print("accuracy score: ",acc)
    c_m=confusion_matrix(y_test,y_pred)
    print("confusion matrix:\n ",c_m)
    print("classification report: \n",classification_report(y_test,y_pred))
    
def mscore(model):
    train_score=model.score(x_train,y_train)
    test_score=model.score(x_test,y_test)
    print("training score",train_score)
    print("testing score",test_score)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=10)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=10)

# %%
mscore(dt)
# Out:
# training score 0.9219812236969893
# testing score 0.9087378640776699

# %%
ypred_dt = dt.predict(x_test)
print(ypred_dt)
# Out:
# [0 0 1 ... 1 0 0]

# %%
eval_model(y_test,ypred_dt)
# Out:
# accuracy score:  0.9087378640776699
# confusion matrix:
#   [[902  28]
#  [ 66  34]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       930
#            1       0.55      0.34      0.42       100
#
#     accuracy                           0.91      1030
#    macro avg       0.74      0.65      0.69      1030
# weighted avg       0.89      0.91      0.90      1030

# %%
from sklearn.tree import plot_tree

# %%
cn = ['no','yes']
fn = x_train.columns
print(fn)
print(cn)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'campagin'],
#       dtype='object')
# ['no', 'yes']

# %%
plot_tree(dt,class_names=cn,filled=True)
plt.show()

# %%
dt1 = DecisionTreeClassifier(criterion='entropy',max_depth=4,min_samples_split=15)
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_split=15)

# %%
mscore(dt)
# Out:
# training score 0.9219812236969893
# testing score 0.9087378640776699

# %%
ypred_dt1 = dt1.predict(x_test)

# %%
eval_model(y_test,ypred_dt1)
# Out:
# accuracy score:  0.9087378640776699
# confusion matrix:
#   [[894  36]
#  [ 58  42]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       930
#            1       0.54      0.42      0.47       100
#
#     accuracy                           0.91      1030
#    macro avg       0.74      0.69      0.71      1030
# weighted avg       0.90      0.91      0.90      1030

# %%
plt.figure(figsize=(15,15))
plot_tree(dt1,class_names=cn,filled=True)
plt.show()
